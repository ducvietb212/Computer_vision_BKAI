# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   #if like me you do not have a lot of memory in your GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "" #then these two lines force keras to use your CPU
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, Dropout, BatchNormalization
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import h5py
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def array_to_color(array, cmap="Oranges"):
    s_m = plt.cm.ScalarMappable(cmap=cmap)
    return s_m.to_rgba(array)[:,:-1]


def rgb_data_transform(data):
    data_t = []
    for i in range(data.shape[0]):
        data_t.append(array_to_color(data[i]).reshape(16, 16, 16, 3))
    return np.asarray(data_t, dtype=np.float32)

# %%
with h5py.File("/kaggle/input/3d-mnist/train_point_clouds.h5", "r") as hf:    
    a = hf["0"]
    b = a['img'][:]
    s = a['points'][:]

# %%
plt.imshow(b)
plt.title('The figure 5 in 2d')
# Out:
# Text(0.5, 1.0, 'The figure 5 in 2d')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s[:,0], s[:,1], zs=s[:,2])
ax.view_init(10, 0)
plt.title('The figure 5 in 3d Cloud point')
# Out:
# Text(0.5, 0.92, 'The figure 5 in 3d Cloud point')

# %%
with h5py.File("/kaggle/input/3d-mnist/full_dataset_vectors.h5", "r") as hf:    

    # Split the data into training/test features/targets
    X_train = hf["X_train"][:]
    targets_train = hf["y_train"][:]
    X_test = hf["X_test"][:] 
    targets_test = hf["y_test"][:]

    # Determine sample shape
    sample_shape = (16, 16, 16, 3)

    # Reshape data into 3D format
    X_train = rgb_data_transform(X_train)
    X_test = rgb_data_transform(X_test)

    # Convert target vectors to categorical targets
    targets_train = to_categorical(targets_train).astype(np.int64)
    targets_test = to_categorical(targets_test).astype(np.int64)

# %%
# Create the model
model = Sequential()
model.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=sample_shape))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(0.5))
model.add(Conv3D(64, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(lr=0.001),
              metrics=['accuracy'])
model.summary()
# Fit data to model
history = model.fit(X_train, targets_train,
            batch_size=128,
            epochs=40,
            verbose=1,
            validation_split=0.3)
# Out:
# 2023-12-12 09:02:22.434858: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 14, 14, 14, 32)    2624
#
#  max_pooling3d (MaxPooling3  (None, 7, 7, 7, 32)       0
#  D)
#
#  batch_normalization (Batch  (None, 7, 7, 7, 32)       128
#  Normalization)
#
#  dropout (Dropout)           (None, 7, 7, 7, 32)       0
#
#  conv3d_1 (Conv3D)           (None, 5, 5, 5, 64)       55360
#
#  max_pooling3d_1 (MaxPoolin  (None, 2, 2, 2, 64)       0
#  g3D)
#
#  batch_normalization_1 (Bat  (None, 2, 2, 2, 64)       256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 2, 2, 2, 64)       0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 258058 (1008.04 KB)
# Trainable params: 257866 (1007.29 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 55/55 [==============================] - 47s 825ms/step - loss: 2.3158 - accuracy: 0.2366 - val_loss: 2.2457 - val_accuracy: 0.2303
# Epoch 2/40
# 55/55 [==============================] - 45s 813ms/step - loss: 1.7556 - accuracy: 0.3874 - val_loss: 2.7256 - val_accuracy: 0.2027
# Epoch 3/40
# 55/55 [==============================] - 44s 809ms/step - loss: 1.5315 - accuracy: 0.4657 - val_loss: 2.4775 - val_accuracy: 0.2663
# Epoch 4/40
# 55/55 [==============================] - 44s 810ms/step - loss: 1.4261 - accuracy: 0.4984 - val_loss: 1.8828 - val_accuracy: 0.3803
# Epoch 5/40
# 55/55 [==============================] - 45s 825ms/step - loss: 1.3492 - accuracy: 0.5210 - val_loss: 2.0934 - val_accuracy: 0.2893
# Epoch 6/40
# 55/55 [==============================] - 45s 819ms/step - loss: 1.2932 - accuracy: 0.5361 - val_loss: 2.2032 - val_accuracy: 0.2817
# Epoch 7/40
# 55/55 [==============================] - 45s 826ms/step - loss: 1.2296 - accuracy: 0.5609 - val_loss: 1.6267 - val_accuracy: 0.4747
# Epoch 8/40
# 55/55 [==============================] - 45s 814ms/step - loss: 1.2133 - accuracy: 0.5689 - val_loss: 2.6241 - val_accuracy: 0.2953
# Epoch 9/40
# 55/55 [==============================] - 45s 811ms/step - loss: 1.1578 - accuracy: 0.5786 - val_loss: 2.6211 - val_accuracy: 0.3470
# Epoch 10/40
# 55/55 [==============================] - 44s 810ms/step - loss: 1.1327 - accuracy: 0.5896 - val_loss: 2.0798 - val_accuracy: 0.4130
# Epoch 11/40
# 55/55 [==============================] - 44s 807ms/step - loss: 1.1032 - accuracy: 0.6026 - val_loss: 3.0866 - val_accuracy: 0.3360
# Epoch 12/40
# 55/55 [==============================] - 45s 811ms/step - loss: 1.0769 - accuracy: 0.6160 - val_loss: 2.8009 - val_accuracy: 0.2750
# Epoch 13/40
# 55/55 [==============================] - 45s 814ms/step - loss: 1.0476 - accuracy: 0.6257 - val_loss: 1.2192 - val_accuracy: 0.5880
# Epoch 14/40
# 55/55 [==============================] - 44s 801ms/step - loss: 1.0408 - accuracy: 0.6253 - val_loss: 1.3561 - val_accuracy: 0.5277
# Epoch 15/40
# 55/55 [==============================] - 44s 805ms/step - loss: 1.0102 - accuracy: 0.6389 - val_loss: 1.4456 - val_accuracy: 0.5123
# Epoch 16/40
# 55/55 [==============================] - 44s 799ms/step - loss: 0.9962 - accuracy: 0.6441 - val_loss: 4.2823 - val_accuracy: 0.2850
# Epoch 17/40
# 55/55 [==============================] - 44s 807ms/step - loss: 0.9760 - accuracy: 0.6536 - val_loss: 4.3955 - val_accuracy: 0.2347
# Epoch 18/40
# 55/55 [==============================] - 44s 800ms/step - loss: 0.9663 - accuracy: 0.6570 - val_loss: 1.2404 - val_accuracy: 0.6110
# Epoch 19/40
# 55/55 [==============================] - 44s 795ms/step - loss: 0.9388 - accuracy: 0.6663 - val_loss: 3.7691 - val_accuracy: 0.2647
# Epoch 20/40
# 55/55 [==============================] - 44s 796ms/step - loss: 0.9257 - accuracy: 0.6689 - val_loss: 4.3591 - val_accuracy: 0.2713
# Epoch 21/40
# 55/55 [==============================] - 44s 800ms/step - loss: 0.9132 - accuracy: 0.6749 - val_loss: 3.0894 - val_accuracy: 0.2940
# Epoch 22/40
# 55/55 [==============================] - 44s 799ms/step - loss: 0.9011 - accuracy: 0.6771 - val_loss: 3.1505 - val_accuracy: 0.3370
# Epoch 23/40
# 55/55 [==============================] - 44s 792ms/step - loss: 0.8892 - accuracy: 0.6840 - val_loss: 3.2967 - val_accuracy: 0.3287
# Epoch 24/40
# 55/55 [==============================] - 43s 775ms/step - loss: 0.8722 - accuracy: 0.6939 - val_loss: 3.3347 - val_accuracy: 0.3233
# Epoch 25/40
# 55/55 [==============================] - 43s 774ms/step - loss: 0.8443 - accuracy: 0.6997 - val_loss: 5.5500 - val_accuracy: 0.2163
# Epoch 26/40
# 55/55 [==============================] - 42s 769ms/step - loss: 0.8586 - accuracy: 0.6923 - val_loss: 1.3591 - val_accuracy: 0.5990
# Epoch 27/40
# 55/55 [==============================] - 42s 767ms/step - loss: 0.8311 - accuracy: 0.7067 - val_loss: 2.4532 - val_accuracy: 0.3107
# Epoch 28/40
# 55/55 [==============================] - 43s 776ms/step - loss: 0.7959 - accuracy: 0.7149 - val_loss: 1.2936 - val_accuracy: 0.5757
# Epoch 29/40
# 55/55 [==============================] - 42s 766ms/step - loss: 0.7838 - accuracy: 0.7241 - val_loss: 1.1270 - val_accuracy: 0.6140
# Epoch 30/40
# 55/55 [==============================] - 43s 782ms/step - loss: 0.7870 - accuracy: 0.7191 - val_loss: 3.2977 - val_accuracy: 0.3757
# Epoch 31/40
# 55/55 [==============================] - 43s 778ms/step - loss: 0.7741 - accuracy: 0.7227 - val_loss: 1.0401 - val_accuracy: 0.6647
# Epoch 32/40
# 55/55 [==============================] - 42s 771ms/step - loss: 0.7620 - accuracy: 0.7293 - val_loss: 4.4336 - val_accuracy: 0.2723
# Epoch 33/40
# 55/55 [==============================] - 42s 772ms/step - loss: 0.7552 - accuracy: 0.7360 - val_loss: 1.0442 - val_accuracy: 0.6580
# Epoch 34/40
# 55/55 [==============================] - 42s 768ms/step - loss: 0.7478 - accuracy: 0.7336 - val_loss: 1.5446 - val_accuracy: 0.5250
# Epoch 35/40
# 55/55 [==============================] - 43s 777ms/step - loss: 0.7151 - accuracy: 0.7439 - val_loss: 1.1857 - val_accuracy: 0.6133
# Epoch 36/40
# 55/55 [==============================] - 43s 781ms/step - loss: 0.7274 - accuracy: 0.7436 - val_loss: 1.2256 - val_accuracy: 0.6033
# Epoch 37/40
# 55/55 [==============================] - 42s 769ms/step - loss: 0.7078 - accuracy: 0.7520 - val_loss: 1.0522 - val_accuracy: 0.6487
# Epoch 38/40
# 55/55 [==============================] - 43s 775ms/step - loss: 0.6715 - accuracy: 0.7616 - val_loss: 1.0562 - val_accuracy: 0.6537
# Epoch 39/40
# 55/55 [==============================] - 42s 770ms/step - loss: 0.6761 - accuracy: 0.7597 - val_loss: 2.4149 - val_accuracy: 0.3957
# Epoch 40/40
# 55/55 [==============================] - 42s 765ms/step - loss: 0.6562 - accuracy: 0.7691 - val_loss: 1.8219 - val_accuracy: 0.4720
